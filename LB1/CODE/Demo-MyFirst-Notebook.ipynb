# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthieRB/Testrepository/blob/main/LB1/CODE/Demo-MyFirst-Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("video_games.csv")

# %%
df.head()
# Out:
#                          Game   Copies sold    Release date[a]  \
# 0         Marvel's Spider-Man    20 million  September 7, 2018
# 1                  God of War  19.5 million     April 20, 2018
# 2  Uncharted 4: A Thief's End    16 million       May 10, 2016
# 3    The Witcher 3: Wild Hunt  10.8 million       May 18, 2015
# 4      The Last of Us Part II    10 million      June 19, 2020
#
#                            Genre(s)         Developer(s)  \
# 0                  Action-adventure      Insomniac Games
# 1   Action-adventure hack and slash  Santa Monica Studio
# 2                  Action-adventure          Naughty Dog
# 3               Action role-playing       CD Projekt Red
# 4  Action-adventure survival horror          Naughty Dog
#
#                      Publisher(s)
# 0  Sony Interactive Entertainment
# 1  Sony Interactive Entertainment
# 2  Sony Interactive Entertainment
# 3                      CD Projekt
# 4  Sony Interactive Entertainment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             33 non-null     object
#  1   Copies sold      33 non-null     object
#  2   Release date[a]  33 non-null     object
#  3   Genre(s)         33 non-null     object
#  4   Developer(s)     33 non-null     object
#  5   Publisher(s)     33 non-null     object
# dtypes: object(6)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#                        Game Copies sold    Release date[a]  \
# count                    33          33                 33
# unique                   33          24                 32
# top     Marvel's Spider-Man   2 million  November 15, 2013
# freq                      1           4                  2
#
#                    Genre(s) Developer(s)                    Publisher(s)
# count                    33           33                              33
# unique                   15           23                              12
# top     Action role-playing  Square Enix  Sony Interactive Entertainment
# freq                     11            4                               8
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Game').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df.columns
# Out:
# Index(['Game', 'Copies sold', 'Release date[a]', 'Genre(s)', 'Developer(s)',
#        'Publisher(s)'],
#       dtype='object')

# %%
df.drop(df[df['Publisher(s)'] == "Konami"].index, inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                          Game   Copies sold  \
# 0                         Marvel's Spider-Man    20 million
# 1                                  God of War  19.5 million
# 2                  Uncharted 4: A Thief's End    16 million
# 3                    The Witcher 3: Wild Hunt  10.8 million
# 4                      The Last of Us Part II    10 million
# 5                           Horizon Zero Dawn    10 million
# 6                   The Last of Us Remastered    10 million
# 7                           Ghost of Tsushima  9.73 million
# 8                       Star Wars Battlefront  8.42 million
# 9                          Gran Turismo Sport     8 million
# 10                        Infamous Second Son     6 million
# 11                      Detroit: Become Human   5.5 million
# 12                   Final Fantasy VII Remake     5 million
# 13                      Monster Hunter: World  4.67 million
# ...

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                                          Game   Copies sold  \
# 0                         Marvel's Spider-Man    20 million
# 1                                  God of War  19.5 million
# 2                  Uncharted 4: A Thief's End    16 million
# 3                    The Witcher 3: Wild Hunt  10.8 million
# 4                      The Last of Us Part II    10 million
# 5                           Horizon Zero Dawn    10 million
# 6                   The Last of Us Remastered    10 million
# 7                           Ghost of Tsushima  9.73 million
# 8                       Star Wars Battlefront  8.42 million
# 9                          Gran Turismo Sport     8 million
# 10                        Infamous Second Son     6 million
# 11                      Detroit: Become Human   5.5 million
# 12                   Final Fantasy VII Remake     5 million
# 13                      Monster Hunter: World  4.67 million
# ...

# %%
print(df)
# Out:
#                                          Game   Copies sold  \
# 0                         Marvel's Spider-Man    20 million
# 1                                  God of War  19.5 million
# 2                  Uncharted 4: A Thief's End    16 million
# 3                    The Witcher 3: Wild Hunt  10.8 million
# 4                      The Last of Us Part II    10 million
# 5                           Horizon Zero Dawn    10 million
# 6                   The Last of Us Remastered    10 million
# 7                           Ghost of Tsushima  9.73 million
# 8                       Star Wars Battlefront  8.42 million
# 9                          Gran Turismo Sport     8 million
# 10                        Infamous Second Son     6 million
# 11                      Detroit: Become Human   5.5 million
# 12                   Final Fantasy VII Remake     5 million
# 13                      Monster Hunter: World  4.67 million
# 14                             Cyberpunk 2077  3.83 million
# ...

# %%
df['Release date[a]'] = pd.to_datetime(df['Release date[a]'])

# %%
print(df)
# Out:
#                                          Game   Copies sold Release date[a]  \
# 0                         Marvel's Spider-Man    20 million      2018-09-07
# 1                                  God of War  19.5 million      2018-04-20
# 2                  Uncharted 4: A Thief's End    16 million      2016-05-10
# 3                    The Witcher 3: Wild Hunt  10.8 million      2015-05-18
# 4                      The Last of Us Part II    10 million      2020-06-19
# 5                           Horizon Zero Dawn    10 million      2017-02-28
# 6                   The Last of Us Remastered    10 million      2014-07-29
# 7                           Ghost of Tsushima  9.73 million      2020-07-17
# 8                       Star Wars Battlefront  8.42 million      2015-11-17
# 9                          Gran Turismo Sport     8 million      2017-10-17
# 10                        Infamous Second Son     6 million      2014-03-21
# ...

# %%
df = df.sort_values(by='Release date[a]', ascending=True)

# %%
print(df)
# Out:
#                                          Game   Copies sold Release date[a]  \
# 23                                      Knack     2 million      2013-11-15
# 19                      Killzone: Shadow Fall   2.1 million      2013-11-15
# 10                        Infamous Second Son     6 million      2014-03-21
# 6                   The Last of Us Remastered    10 million      2014-07-29
# 24           Minecraft: PlayStation 4 Edition     2 million      2014-09-04
# 22                                  Driveclub     2 million      2014-10-07
# 20                         Grand Theft Auto V  2.02 million      2014-11-18
# 21                                 Bloodborne     2 million      2015-03-24
# 3                    The Witcher 3: Wild Hunt  10.8 million      2015-05-18
# 8                       Star Wars Battlefront  8.42 million      2015-11-17
# 2                  Uncharted 4: A Thief's End    16 million      2016-05-10
# ...

# %%
df = df.sort_values(by='Release date[a]', ascending=False)

# %%
print(df)
# Out:
#                                          Game   Copies sold Release date[a]  \
# 14                             Cyberpunk 2077  3.83 million      2020-12-10
# 7                           Ghost of Tsushima  9.73 million      2020-07-17
# 4                      The Last of Us Part II    10 million      2020-06-19
# 12                   Final Fantasy VII Remake     5 million      2020-04-10
# 26                                     Nioh 2   1.4 million      2020-03-12
# 18                            Persona 5 Royal   2.3 million      2019-10-31
# 31                         Kingdom Hearts III     1 million      2019-01-25
# 0                         Marvel's Spider-Man    20 million      2018-09-07
# 11                      Detroit: Become Human   5.5 million      2018-05-25
# 1                                  God of War  19.5 million      2018-04-20
# 13                      Monster Hunter: World  4.67 million      2018-01-26
# ...
