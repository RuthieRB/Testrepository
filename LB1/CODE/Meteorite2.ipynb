# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthieRB/Testrepository/blob/main/LB1/CODE/Meteorite2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/meteorite_landings.csv')

# %%
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation  Unnamed: 10
# 0    6.08333     (50.775, 6.08333)          NaN
# 1   10.23333  (56.18333, 10.23333)          NaN
# 2 -113.00000    (54.21667, -113.0)          NaN
# 3  -99.90000     (16.88333, -99.9)          NaN
# 4  -64.95000   (-33.16667, -64.95)          NaN

# %%
df.describe()
# Out:
#                  id      mass (g)          year        reclat       reclong  \
# count  45716.000000  4.558500e+04  45425.000000  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04   1991.828817    -39.122580     61.074319
# std    16860.683030  5.749889e+05     25.052766     46.378511     80.647298
# min        1.000000  0.000000e+00    860.000000    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00   1987.000000    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01   1998.000000    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02   2003.000000      0.000000    157.166670
# max    57458.000000  6.000000e+07   2101.000000     81.166670    354.473330
#
#        Unnamed: 10
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 9999
print(df)
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation  Unnamed: 10
# ...

# %%
import pandas as pd
df = pd.read_csv('sample_data/meteorite_landings.csv')
df.dropna(inplace = True)
print(pd.options.display.max_rows)
pd.options.display.max_rows = 9999
print(df)
# Out:
# 9999
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation, Unnamed: 10]
# Index: []

# %%
pd.options.display.max_rows = 9999
print(df)
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation, Unnamed: 10]
# Index: []

# %%
print(df['name'])
# Out:
# Series([], Name: name, dtype: object)

# %%
import pandas as pd
df = pd.read_csv('sample_data/meteorite_landings.csv')

# %%
pd.options.display.max_rows = 9999
print(df)
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation  Unnamed: 10
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
#  10  Unnamed: 10  0 non-null      float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 3.8+ MB
# None

# %%
print(df.iloc[15])
# Out:
# name                      Akwanga
# id                            432
# nametype                    Valid
# recclass                        H
# mass (g)                   3000.0
# fall                         Fell
# year                       1959.0
# reclat                    8.91667
# reclong                   8.43333
# GeoLocation    (8.91667, 8.43333)
# Unnamed: 10                   NaN
# Name: 15, dtype: object

# %%
df['Unnamed: 10'].fillna("ohne Namen", inplace = True)
print(df)
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation Unnamed: 10
# ...

# %%
print(df.iloc[35:100])
# Out:
#                       name     id nametype         recclass  mass (g)   fall  \
# 35               Andreevka   2296    Valid               L3     600.0   Fell
# 36                  Andura   2298    Valid               H6   17900.0   Fell
# 37   Northwest Africa 5815  50693    Valid               L5     256.8  Found
# 38                  Angers   2301    Valid               L6       NaN   Fell
# 39  Angra dos Reis (stone)   2302    Valid          Angrite    1500.0   Fell
# 40                 Ankober   2304    Valid               H4    6500.0   Fell
# 41                  Anlong   2305    Valid               H5    2500.0   Fell
# 42                  Aomori   2313    Valid               L6     320.0   Fell
# 43           Appley Bridge   2318    Valid              LL6   15000.0   Fell
# 44                     Apt   2320    Valid               L6    3200.0   Fell
# 45              Arbol Solo   2325    Valid               H5     810.0   Fell
# ...

# %%
import pandas as pd

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Filter the DataFrame
stone_df = df[df['name'].str.contains('(stone)', case=False, na=False)]

# Print the filtered DataFrame
print(stone_df)
# Out:
#                           name     id nametype            recclass   mass (g)  \
# 6          Adzhi-Bogdo (stone)    390    Valid               LL3-6     910.00
# 39      Angra dos Reis (stone)   2302    Valid             Angrite    1500.00
# 76           Barcelona (stone)   4944    Valid                  OC        NaN
# 309          Frankfort (stone)  10177    Valid           Howardite     650.00
# 772           Pavlodar (stone)  18175    Valid                  H5     142.50
# 788    Phillips County (stone)  18808    Valid                  L6   57900.00
# 1069       Whetstone Mountains  49514    Valid                  H5    2138.74
# 1623             Albin (stone)    456    Valid                   L   15400.00
# 1630         al-Ghanim (stone)    469    Valid                  L6    3755.00
# 5161              Boaz (stone)   5091    Valid                  H5    1800.00
# 5499         Coldwater (stone)   5399    Valid                  H5   16000.00
# ...

# %%
import pandas as pd

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Filter the DataFrame
iron_df = df[df['recclass'].str.contains('iron', case=False, na=False)]

# Print the filtered DataFrame
print(iron_df)
# Out:
#                                name     id nametype           recclass  \
# 16                          Akyumak    433    Valid          Iron, IVA
# 61                             Avce   4906    Valid         Iron, IIAB
# 66                           Bahjoi   4922    Valid      Iron, IAB-sLL
# 70                      Ban Rong Du   4934    Valid    Iron, ungrouped
# 129                           Bogou   5097    Valid       Iron, IAB-MG
# 130                      Boguslavka   5098    Valid         Iron, IIAB
# 141                         Braunau   5133    Valid         Iron, IIAB
# 147                       Bulls Run   5163    Valid              Iron?
# 158                     Cabin Creek   5186    Valid        Iron, IIIAB
# 187                       Charlotte   5328    Valid          Iron, IVA
# 203                        Chisenga   5355    Valid        Iron, IIIAB
# 278                         Elbogen   7823    Valid          Iron, IID
# ...

# %%
import pandas as pd

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Filter the DataFrame
iron_df = df[df['recclass'].str.contains('iron', case=False, na=False)]

# Print the filtered DataFrame
iron_count = len(iron_df)
print(f"Number of rows containing 'iron' in 'recclass': {iron_count}")
# Out:
# Number of rows containing 'iron' in 'recclass': 1070

# %%
import pandas as pd

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Filter the DataFrame
filtered_df = df[df['name'].str.startswith('Ber', na=False)]

# Print or work with the filtered DataFrame
print(filtered_df)
# Out:
#                name     id nametype       recclass  mass (g)   fall    year  \
# 101          Berduc  48975    Valid             L6     270.0   Fell  2008.0
# 103   Berlanguillas   5029    Valid             L6    1440.0   Fell  1811.0
# 104        Berthoud  47355    Valid  Eucrite-mmict     960.0   Fell  2004.0
# 5092      Berdyansk   5027    Valid             L6    2250.0  Found  1843.0
# 5093    Bernic Lake  54851    Valid   Iron, IAB-MG    9162.0  Found  2002.0
#
#         reclat    reclong             GeoLocation  Unnamed: 10
# 101  -31.91000  -58.32833     (-31.91, -58.32833)          NaN
# 103   41.68333   -3.80000        (41.68333, -3.8)          NaN
# 104   40.30583 -105.02325  (40.30583, -105.02325)          NaN
# 5092  46.75000   36.81667       (46.75, 36.81667)          NaN
# 5093  50.43845  -95.52937   (50.43845, -95.52937)          NaN

# %%
import pandas as pd

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Filter the DataFrame
filtered_df = df[df['name'].str.startswith('a', na=False)]

# Get the number of lines
num_lines = len(filtered_df)  # Using len()
# or
num_lines = filtered_df.shape[0]  # Using shape attribute

# Print the number of lines
print(f"Number of lines in the filtered dataset: {num_lines}")
# Out:
# Number of lines in the filtered dataset: 8

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Extract the relevant columns
year = df['year']
meteorite_id = df['id']

# Create the scatter plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.scatter(year, meteorite_id, alpha=0.5)  # alpha for transparency
plt.xlabel('Year')
plt.ylabel('Meteorite ID')
plt.title('Relationship between Year and Meteorite ID')
plt.grid(True)  # Add grid lines for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data (adjust path if needed)
df = pd.read_csv('sample_data/meteorite_landings.csv')

# Extract the relevant columns
year = df['year']
meteorite_id = df['id']

# Create the scatter plot with color parameters
plt.figure(figsize=(10, 6))
plt.scatter(year, meteorite_id, alpha=0.5, c='green', marker='x', s=20)
plt.xlabel('Year')
plt.ylabel('Meteorite ID')
plt.title('Relationship between Year and Meteorite ID')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Erste Schritte</strong>
# </div>
#
# Das Dokument, das Sie lesen, ist keine statische Webseite, sondern eine interaktive Umgebung, die als <strong>Colab-Notebook</strong> bezeichnet wird und in der Sie Code schreiben und ausführen können.
#
# Hier ist beispielsweise eine <strong>Codezelle</strong> mit einem kurzen Python-Script, das einen Wert berechnet, ihn in einer Variablen speichert und das Ergebnis ausgibt:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Wählen Sie zum Ausführen des Codes in der Zelle oben die Zelle mit einem Klick aus und drücken Sie dann entweder die Schaltfläche zum Abspielen links neben dem Code oder verwenden Sie die Tastenkombination "Befehlstaste/Strg + Enter". Klicken Sie zum Bearbeiten des Codes einfach auf die Zelle und beginnen Sie mit der Bearbeitung.
#
# Variablen, die Sie in einer Zelle definieren, können später in anderen Zellen verwendet werden:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Mit Colab-Notebooks können Sie <strong>ausführbaren Code</strong> und <strong>Rich Text</strong> in einem einzigen Dokument gemeinsam mit <strong>Bildern</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> und vielem mehr kombinieren. Wenn Sie Ihre eigenen Colab-Notebooks erstellen, werden sie in Ihrem Google Drive-Konto gespeichert. Sie können Ihre Colab-Notebooks ganz einfach mit Kollegen oder Freunden teilen und das Kommentieren oder sogar das Bearbeiten Ihrer Notebooks zulassen. Weitere Informationen finden Sie unter <a href="/notebooks/basic_features_overview.ipynb">Übersicht über Colab</a>. Wenn Sie ein neues Colab-Notebook erstellen möchten, können Sie oben das Menü "Datei" oder den folgenden Link verwenden: <a href="http://colab.research.google.com#create=true">Ein neues Colab-Notebook erstellen</a>.
#
# Colab-Notebooks sind Jupyter-Notebooks, die von Colab gehostet werden. Weitere Informationen zu Project Jupyter finden Sie unter <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data Science
# </div>
#
# Mit Colab können Sie das volle Potenzial der beliebten Python-Bibliotheken nutzen, um Daten zu analysieren und visualisieren. Die Codezelle unten verwendet <strong>NumPy</strong>, um zufällige Daten zu erstellen, und <strong>Matplotlib</strong>, um sie zu visualisieren. Klicken Sie zum Bearbeiten des Codes einfach auf die Zelle und beginnen Sie mit der Bearbeitung.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
# @title id

from matplotlib import pyplot as plt
df['id'].plot(kind='hist', bins=20, title='id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Sie können Ihre eigenen Daten aus Ihrem Google Drive-Konto in Colab-Notebooks importieren, beispielsweise aus Tabellen sowie aus GiHhub und vielen anderen Quellen. Weitere Informationen zum Importieren von Daten und dazu, wie Colab für Data Science genutzt werden kann, finden Sie unten in den Links unter <a href="#working-with-data">Mit Daten arbeiten</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Maschinelles Lernen
# </div>
#
# Mit Colab können Sie einen Bilddatenbestand importieren, damit einen Bildklassifikator trainieren und das Modell bewerten – alles in <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">nur wenigen Codezeilen</a>. Colab-Notebooks führen Code auf den Cloud-Servern von Google aus und bieten so unabhängig von der Leistung Ihres Computers die Vorteile der Google-Hardware, wie z. B. <a href="#using-accelerated-hardware">GPUs und TPUs</a>. Sie benötigen lediglich einen Browser.

# %% [markdown]
# Colab wird im Bereich des maschinellen Lernens in großem Umfang u. a. mit folgenden Anwendungen eingesetzt:
# - Erste Schritte mit TensorFlow
# - Neuronale Netzwerke entwickeln und trainieren
# - Tests mit TPUs durchführen
# - Verbreitung der KI-Forschung
# - Anleitungen erstellen
#
# Colab-Beispiel-Notebooks, in denen Anwendungen für maschinelles Lernen veranschaulicht werden, finden Sie unten in den <a href="#machine-learning-examples">Beispielen für maschinelles Lernen</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Weitere Ressourcen
#
# ### Mit Notebooks in Colab arbeiten
#
# </div>
#
# - [Übersicht über Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Leitfaden zu Markdown](/notebooks/markdown_guide.ipynb)
# - [Bibliotheken importieren und installieren](/notebooks/snippets/importing_libraries.ipynb)
# - [Notebooks in GitHub werden gespeichert und geladen](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interaktive Formulare](/notebooks/forms.ipynb)
# - [Interaktive Widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Mit Daten arbeiten
# </div>
#
# - [Daten laden: Drive, Tabellen und Google Cloud Storage](/notebooks/io.ipynb)
# - [Diagramme: Daten visualisieren](/notebooks/charts.ipynb)
# - [Erste Schritte mit BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# Hier sehen Sie einige Notebooks aus dem Machine Learning Crash Course von Google. Weitere Informationen finden Sie auf der <a href="https://developers.google.com/machine-learning/crash-course/">Website des vollständigen Kurses</a>.
# - [Einführung in Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Lineare Regression mit tf.keras und synthetischen Daten](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Beschleunigte Hardware verwenden
# </div>
#
# - [TensorFlow mit GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow mit TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Vorgestellte Beispiele
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>: Mit dem NeMo-Toolkit für Conversational AI von Nvidia können Sie eine Stimme in einem Audiofragment in eine computergenerierte Stimme umwandeln.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Erneutes Trainieren eines Bildklassifikators</a>: Erstellen Sie auf Grundlage eines zuvor trainierten Bildklassifikators ein Keras-Modell, mit dem Blumen auseinandergehalten werden können.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Textklassifizierung</a>: Klassifizieren Sie Filmrezensionen in der IMDB als <em>positiv</em> oder <em>negativ</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Stilübertragung</a>: Übertragen Sie den Stil eines Bildes, mithilfe von Deep Learning, auf ein anderes Bild.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Fragen und Antworten zum mehrsprachigen universellen Satz-Encoder</a>: Verwenden Sie zum Beantworten von Fragen aus dem SQuAD-Dataset ein Modell für maschinelles Lernen.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Videointerpolation</a>: Machen Sie eine Vorhersage darüber, was zwischen dem ersten und dem letzten Bild eines Videos geschah.
